# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys

# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("titanic_train.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# why are we doing EDA part ?

### for model building to analyze the data first.
### Analysis, reporting and presentation
### Validate Assumptions
### Handling missing value/outlier/Encoding- Data Preprocessing
### Feature Engineering

# %%
# check missing value

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()/len(df) *100
# Out:
# 19.865319865319865

# %%
# Fare

df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['Fare'] > 100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
df[df['Fare'] > 100].shape[0]
# Out:
# 53

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Steps of doing univariate Analysis on Categorical Variable

df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Embarked'].value_counts().plot(kind = 'pie',autopct = "%0.1f%%")
# Out:
# <Axes: ylabel='Embarked'>

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
# Find the total missing value and then create new column with missing value percentage

(df.isnull().sum()/df.shape[0] * 100).reset_index().rename(columns = {0: "missing_value(%)"})
# Out:
#           index  missing_value(%)
# 0   PassengerId          0.000000
# 1      Survived          0.000000
# 2        Pclass          0.000000
# 3          Name          0.000000
# 4           Sex          0.000000
# 5           Age         19.865320
# 6         SibSp          0.000000
# 7         Parch          0.000000
# 8        Ticket          0.000000
# 9          Fare          0.000000
# 10        Cabin         77.104377
# 11     Embarked          0.224467

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Bivariate Analysis
#
# ### Select two column
# ### Numerical - Numerical/Num-Categorical/Categorical- Categorical

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize = 'columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df['Survived'],df['Pclass'],normalize = 'columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# Survived and Age

df[df['Survived'] ==1]['Age'].plot(kind = 'kde', label = 'Survived')
df[df['Survived'] ==0]['Age'].plot(kind = 'kde', label = 'Not Survived')

plt.legend()
plt.show()

# %%
df[df['Survived'] == 0]['Age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['invidual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['invidual_fare'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[['invidual_fare','Fare']].describe()
# Out:
#        invidual_fare        Fare
# count     891.000000  891.000000
# mean       19.916375   32.204208
# std        35.841257   49.693429
# min         0.000000    0.000000
# 25%         7.250000    7.910400
# 50%         8.300000   14.454200
# 75%        23.666667   31.000000
# max       512.329200  512.329200

# %%
# Travel with Family (sibsp and parch)

df['Family_size'] = df['SibSp'] +df['Parch'] + 1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  invidual_fare  Family_size
# 0      0         A/5 21171   7.2500   NaN        S        3.62500            2
# 1      0          PC 17599  71.2833   C85        C       35.64165            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        7.92500            1
# ...

# %%
df['Family_size'].value_counts()
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: Family_size, dtype: int64

# %%
# family size
# 1->along
# 2-4 -> small family
# > 5 -> Large family

def transform_family(num):
    if num == 1:
        return "alone"
    elif num > 1and num < 5:
        return "small family"
    else:
        return "Large family"

# %%
df['family_type'] = df['Family_size'].apply(transform_family)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family_type'].value_counts()
# Out:
# alone           537
# small family    292
# Large family     62
# Name: family_type, dtype: int64

# %%
sns.pairplot(df,hue = "Survived", size=3)
plt.show()

# %% [markdown]
# # pandas profiling - EDA automation

# %%
pip install ydata-profiling
# Out:
# ...
#
# ...
#                                               0.0/356.2 kB ? eta -:--:--
#      ------------                           112.6/356.2 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 356.2/356.2 kB 4.4 MB/s eta 0:00:00
# ...
#                                               0.0/104.8 kB ? eta -:--:--
#      -------------------------------------- 104.8/104.8 kB 5.9 MB/s eta 0:00:00
# ...
#   Using cached wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
# ...
#                                               0.0/11.6 MB ? eta -:--:--
#      --                                       0.6/11.6 MB 12.6 MB/s eta 0:00:01
#      ----                                     1.4/11.6 MB 17.5 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 12.4 MB/s eta 0:00:01
#      -------                                  2.1/11.6 MB 11.0 MB/s eta 0:00:01
#      -------                                  2.1/11.6 MB 9.5 MB/s eta 0:00:02
# ...

# %%
from pandas_profiling import ProfileReport

# %%
prof = ProfileReport(df)
prof.to_file(output_file = 'output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),annot = True, cmap = 'coolwarm',linewidth=.5)
# Out:
# <Axes: >
